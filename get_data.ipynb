# %% [markdown]
# <a href="https://colab.research.google.com/github/ruantos/Brazil-Gregorian-Chants-Project/blob/main/get_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
URL = "./lista_paises.html"
tables_list = pd.read_html(URL)

# %%
data = tables_list[0]
# Out:
#     Posição    País (ou território dependente) Estimativa da ONU  \
# 0         1                              Índia     1 417 492 000
# 1         2                      China[nota 1]     1.407.934.000
# 2         3                     Estados Unidos       342.181.000
# 3         4                          Indonésia       285.783.000
# 4         5                          Paquistão       256 204 000
# ..      ...                                ...               ...
# 245       –     Ilha de Ascensão (Reino Unido)             1 100
# 246     195                           Vaticano               879
# 247       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248       –     Tristão da Cunha (Reino Unido)               264
# 249       –       Ilhas Pitcairn (Reino Unido)                67
#
#     Crescimento desde a última estimativa      Estimativa Oficial
# 0                             -12 692 000      Estimativa oficial
# ...

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.head()
# Out:
#   Posição País (ou território dependente) Estimativa da ONU  \
# 0       1                           Índia     1 417 492 000
# 1       2                   China[nota 1]     1.407.934.000
# 2       3                  Estados Unidos       342.181.000
# 3       4                       Indonésia       285.783.000
# 4       5                       Paquistão       256 204 000
#
#   Crescimento desde a última estimativa  Estimativa Oficial
# 0                           -12 692 000  Estimativa oficial
# 1                            -1 390 000       Censo oficial
# 2                            -2 084 000       Censo oficial
# 3                            +3 337 000  Estimativa oficial
# 4                            +6 567 000  Estimativa oficial
